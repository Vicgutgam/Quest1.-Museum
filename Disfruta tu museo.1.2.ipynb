# %%
sala_principail=[]
jardín=['banco','árbol']
tienda=['Disco de música para trabajar', ]
maton=['monedero','teléfono','fotos con la abuelita']
guardarropa=[maton]
mochila={'monedero': 1.50}
inventario=['mochila']

si = ['si', 's', 'vale', 'ok']
no = ['no', 'n']

si_o_no = si + no

def si_no():
  answer = ''
  while answer not in si_o_no:
    answer = input("si o no?")

  return answer

def elige(opcion1, opcion2):
  opciones = [opcion1, opcion2]
  answer = ''
  while answer not in opciones:
    answer = input(f"{opcion1} o {opcion2}")

  return answer

#En presentación podría hacer que si la respuesta no es si o no hacer que no se acepte su visita por insolente.
print('¡Hola!')
print('Bienvenido al museo IRONHACK, nos honra tu visita y esperemos que disfrutes enormemente de tu paseo por nuestra sala, el jardín o la tienda. ¿Es la primera vez que vienes a este museo?')

#Para mejorar esta interancción podría hacerse un conteo de respuestas. Si supera las 3 automaticamente queda expulsado del museo.
presen_2=si_no()
if presen_2 in si or no:
    print('La verdad es que este museo es fantastico tanto si has estado mil vez como si has venido es tu primera vez y eso es así porque se respentan las normas. Como respetar el horario, no hacer fotos con flash o no ser amigo de lo ajeno.')
print('BIENVENIDO')


#SALA 1: GUARDARROPA. De cara al futuro, aquí se podría incluir elementos que trabajasen mejor el inventario.

print('Estas en el pasillo principal, ¿Quieres ir primero a dejar la mochila en el guardarropa?')

pasillo=si_no()
if pasillo in si:
    
    print('Entras en el guardarropa. ¿Quieres "dejar" tu mochila y volver al pasillo o "explorar" la habiatación?')
    
    guar1=elige('dejar', 'explorar')
    
    if guar1 =='dejar':
        print('Has dejado tu mochila en el guardarropa y ahora puedes visitar ligeramente el museo.')
    else:
        guar1=='exporar'
        print('Encuentras en la habitación la mochila del matón de la clase. Tu curiosidad es fuerte y ves que tiene un monedero, un teléfono y unas fotos con su abuelita.')
        print('¿Quieres cogerlo todo para así darle su merecido? ')
        guar2 = si_no()

        if guar2 in si:
            print('Los nervios ante lo que acabas de hacer te impulsa a salir corriendo del guardarropa directo al pasillo.')

        else:
            print('El no decir un SI demuestra que eres una persona con grandes valores... pero por si acaso te vas al pasillo principal para evitar posibles tentaciones.')

else:
    print ('Bueno, cargarás con tu mochila el resto de tu visita... pero ten cuidado con ella.')

#SALA 2: TIENDA. Aquí se presentan por primera vez las opcciones de un GAME OVER. Presenta posibilidades de actualizar inventario de cara al futuro.


print('Estas en el pasillo. Aquí tienes dos opciones, ir a la "tienda" o "continuar" en dirección a la sala principal. ¿Qué eliges? ')
pasillo1= elige('tienda', 'continuar')

if pasillo1=="continuar":
    print('¡Perfecto! No perdamos más el tiempo y vayamos ya a ver lo importante')
else:
    if guar2 in no:
        print('Esta tienda tiene cosas muy interesantes que te podrían ayudar en tu día a día en el mundo de los datos. Entre ellos te llama la atención de un libro que estabas detrás de el mucho tiempo, pero no tienes suficiente dinero. Pero.... la dependienta no está mirando')
        print('¿Quieres robarlo ahora que no te mira la dependienta?''¿"si"o "no"?')
        robo=si_no()
        if robo in si:
                print('!MUY BIEN¡ Has cogido el libro sin que la dependienta se diera cuenta, pero si el guarda de seguridad que estaba detrás tuya, el cual te lleva fuera del museo y te prohibe la entrada para SIEMPRE')
                print ('GAME OVER')
        else:
            print('Ya has ojeado todo lo que hay en la tienda, otro día podrás comprar las cosas que quieras')
    else:
            print('Esta tienda tiene cosas muy interesantes que te podrían ayudar en tu día a día en el mundo de los datos. Entre ellos te llama la atención de un libro que estabas detrás de el mucho tiempo, revisas en tu cartera y no tienes suficiente dinero pero en la cartera del maton hay dinero suficiente para comprate todo lo que quieras... ¿De donde lo habrá sacado?... Aún así no sabes si es la mejor opción')
            print('¿Qué prefieres?')
            tienda=elige('comprar','robar')
            if tienda =='robar':
                print('!MUY BIEN¡ Has cogido el libro sin que la dependienta se diera cuenta, pero si el guarda de seguridad que estaba detrás tuya, el cual te lleva fuera del museo y te prohibe la entrada para SIEMPRE')
                print ('GAME OVER')
            else:
                print('Haces bien, eres un chico con valores... Bueno, acabas de robarle la mochila a otro niño, pero estas mejorando')
                print('Te acercas a la dependienta y cuando vas a pagar los nervios hacen que se te caiga la cartera y hace que pueda ver todo el dinero.')
                print('La dependienta te pregunta''Ey, ¿De dónde has sacado tu tanto dinero')
                print('Estas muy nervioso pero algo le tienes que decir')
                dependienta1 = elige ("regalo de la abuela" , "a usted no le importa")
                if dependienta1=="regalo de la abuela":
                    print('Dependienta: Que buena abuela tienes, espero que disfrutes del libro')
                    print('No sabes cómo has podido escapar de esta... será mejor que sigas tu camino hacia la sala de exposiciones')
                else:
                    print('Dependienta: ¡ERES UN MALEDUCADO! ¡SEGURIDAD!')
                    print('GAME OVER')

#SALA 3: SALA DE EXPOSICIÓN. El hecho de que el código diga que está en obra no es más que una representación de que hay mucho por hacer.
print('Por fin llegas a la sala de exposición... has esperado toda la semana para este momento, pero... un momento. ¿Qué dice ese cartel de la puerta?''\n''ESTA SALA ESTA CERRADA POR REFORMAS''\n''DISCULPEN LAS MOLESTIAS''\n' 'Bueno, pues tendremos que venir otro día')
print('GAME OVER')
